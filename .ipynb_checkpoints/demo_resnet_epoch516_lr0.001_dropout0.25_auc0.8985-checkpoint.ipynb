# %% [markdown]
# # Run ADBench
# - Here we provide a demo for testing AD algorithms on the datasets proposed in ADBench.
# - Feel free to evaluate any customized algorithm in ADBench.
# - For reproducing the complete experiment results in ADBench, please run the code in the run.py file.

# %%
import numpy as np
from glob import glob
import pickle
import random
from tqdm import tqdm
import pandas as pd
# Out:
# D:\autosoftware\anconda\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 加载训练集的pkl文件，划分训练集与验证集
# 训练集的label存放在pkl里面，可以通过它并区分正常片段和异常片段
# 注意需要输入训练集对应的路径

# %%
ind_pkl_files = []#存放标签为0的文件
ood_pkl_files = []#存放标签为1的文件
data_path='Train'#存放数据的路径
pkl_files = glob(data_path+'/*.pkl')
for each_path in tqdm(pkl_files):
    pic = open(each_path,'rb')
    this_pkl_file= pickle.load(pic)#下载pkl文件
    if this_pkl_file[1]['label'] == '00':
        ind_pkl_files.append(each_path)
    else:
        ood_pkl_files.append(each_path)

random.seed(0)
#排序并打乱存放车辆序号的集合
random.shuffle(ind_pkl_files)
random.shuffle(ood_pkl_files)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 28389/28389 [05:00<00:00, 94.56it/s]

# %%
print(len(ind_pkl_files))
print(len(ood_pkl_files))
# Out:
# 23735
# 4654

# %%
train_pkl_files=[]
for j in range(len(ind_pkl_files)//4,len(ind_pkl_files)):
#for j in range(len(ind_pkl_files)):
    train_pkl_files.append(ind_pkl_files[j])
#for i in range(len(ind_pkl_files)//4):
#    train_pkl_files.append(ind_pkl_files[i])
for j in range(len(ood_pkl_files)):
    train_pkl_files.append(ood_pkl_files[j])
print(len(train_pkl_files))
test_pkl_files=[]
#for j in range(len(ind_pkl_files)//4,len(ind_pkl_files)):
 #   test_pkl_files.append(ind_pkl_files[j])
for i in range(len(ind_pkl_files)//4):
    test_pkl_files.append(ind_pkl_files[i])
#for item in ood_pkl_files:
#    test_pkl_files.append(item)

for j in range(len(ood_pkl_files)//4):
    test_pkl_files.append(ood_pkl_files[j])
print(len(test_pkl_files))
# Out:
# 22456
# 7096

# %% [markdown]
# # 定义加载函数，并对数据进行正则化

# %%
def  load_data(pkl_list,label=True):
    '''
    输入pkl的列表，进行文件加载
    label=True用来加载训练集
    label=False用来加载真正的测试集，真正的测试集无标签
    '''
    X = []
    y = []
    

    for  each_pkl in pkl_list:
        pic = open(each_pkl,'rb')
        item= pickle.load(pic)#下载pkl文件
        # 此处选取的是每个滑窗的最后一条数据，仅供参考，可以选择其他的方法，比如均值或者其他处理时序数据的网络
        # 此处选取了前7个特征，可以需求选取特征数量
        feature = item[0][:,0:7][-1]
        #feature = item[0][:,0:7][-1]
        #feature = item[0][:,0:7].mean(axis=0)
        #feature = np.append(item[0][:,0:7][-1],(item[0][:,3][-1] - item[0][:,4][-1])) #加max_single_volt - min_single_volt 一列为特征
        feature=np.append(feature,item[1]["mileage"])
        X.append(feature)
        if label:
            y.append(int(item[1]['label'][0]))
    X = np.vstack(X)
    if label:
        y = np.vstack(y)
    return X, y

# %%
X_train,y_train=load_data(train_pkl_files)
X_test,y_test=load_data(test_pkl_files)
_mean = np.mean(X_train, axis=0)
_std = np.std(X_train, axis=0)
X_train = (X_train - _mean) / (_std + 1e-4)
X_test = (X_test - _mean) / (_std + 1e-4)

# %%
from sklearn.utils import shuffle
# 进行随机打乱，这里random_state指定为固定值，则打乱结果相同
X_train,y_train = shuffle(X_train,y_train,random_state=40)

# %%
data_path3='Test_A'
test1_files = glob(data_path3+'/*.pkl')
X_val,_=load_data(test1_files,label=False)
_mean = np.mean(X_val, axis=0)
_std = np.std(X_val, axis=0)
X_val = (X_val - _mean) / (_std + 1e-4)

# %%
import sklearn.metrics
from sklearn.model_selection import train_test_split
import sklearn.preprocessing
import torch
import torch.nn as nn
import torch.nn.functional as F
# import zero
import delu # the new version of zero package
import rtdl
import scipy
import platform
from myutils import Utils
utils = Utils() # utils function


class FTTransformer():
    '''
    The original code: https://yura52.github.io/rtdl/stable/index.html
    The original paper: "Revisiting Deep Learning Models for Tabular Data", NIPS 2019
    '''
    def __init__(self, seed:int, model_name:str, n_epochs=100, batch_size=64):

        self.seed = seed
        self.model_name = model_name
        self.utils = Utils()

        # device
        if model_name == 'FTTransformer':
            self.device = self.utils.get_device(gpu_specific=True)
        else:
            self.device = self.utils.get_device(gpu_specific=False)

        # Docs: https://yura52.github.io/zero/0.0.4/reference/api/zero.improve_reproducibility.html
        # zero.improve_reproducibility(seed=self.seed)
        delu.improve_reproducibility(base_seed=int(self.seed))

        # hyper-parameter
        self.n_epochs = n_epochs # default is 1000
        self.batch_size = batch_size # default is 256

    def apply_model(self, x_num, x_cat=None):
        if isinstance(self.model, rtdl.FTTransformer):
            return self.model(x_num, x_cat)
        elif isinstance(self.model, (rtdl.MLP, rtdl.ResNet)):
            assert x_cat is None
            return self.model(x_num)
        else:
            raise NotImplementedError(
                f'Looks like you are using a custom model: {type(self.model)}.'
                ' Then you have to implement this branch first.'
            )

    @torch.no_grad()
    def evaluate(self, X, y=None):
        self.model.eval()
        score = []
        # for batch in delu.iter_batches(X[part], 1024):
        for batch in delu.iter_batches(X, self.batch_size):
            score.append(self.apply_model(batch))
        score = torch.cat(score).squeeze(1).cpu().numpy()
        score = scipy.special.expit(score)

        # calculate the metric
        if y is not None:
            target = y.cpu().numpy()
            metric = self.utils.metric(y_true=target, y_score=score)
        else:
            metric = {'aucroc': None, 'aucpr': None}

        return score, metric['aucpr']

    def fit(self, X_train, y_train, ratio=None,X_test=X_test,y_test=y_test):
        # set seed
        self.utils.set_seed(self.seed)
       
        #X_train, X_test_val, y_train, y_test_val = train_test_split(X_train, y_train, test_size=0.33, random_state=42)
        # training set is used as the validation set in the anomaly detection task
        X = {'train': torch.from_numpy(X_train).float().to(self.device),
             'val': torch.from_numpy(X_train).float().to(self.device)}

        y = {'train': torch.from_numpy(y_train).float().to(self.device),
             'val': torch.from_numpy(y_train).float().to(self.device)}
        
       #training set is used as the validation set in the anomaly detection task
#         X = {'train': torch.from_numpy(X_train).float().to(self.device),
#             'val': torch.from_numpy(X_test_val).float().to(self.device)}

#         y = {'train': torch.from_numpy(y_train).float().to(self.device),
#             'val': torch.from_numpy(y_test_val).float().to(self.device)}

        task_type = 'binclass'
        n_classes = None
        d_out = n_classes or 1


        if self.model_name == 'ResNet':
            self.model = rtdl.ResNet.make_baseline(
                d_in=X_train.shape[1],
                d_main=128,
                d_hidden=256,
                dropout_first=0.25,
                dropout_second=0,
                n_blocks=3,
                d_out=d_out,
            )
            lr = 0.001
            weight_decay = 0.0
        
        elif self.model_name == 'MLP':
            self.model = rtdl.MLP.make_baseline(
            d_in=X_train.shape[1],
            d_layers= [128, 256, 128],
            dropout=0.25,
            d_out=d_out,
            )
            lr = 0.001
            weight_decay = 0.0

        elif self.model_name == 'FTTransformer':
            self.model = rtdl.FTTransformer.make_default(
                n_num_features=X_train.shape[1],
                cat_cardinalities=None,
                last_layer_query_idx=[-1],  # it makes the model faster and does NOT affect its output
                d_out=d_out,
            )
            
        elif self.model_name == 'FTTransformer_baseline':
            self.model = rtdl.FTTransformer.make_baseline(
                n_num_features=X_train.shape[1],
                cat_cardinalities=None,
                d_token=X_train.shape[1],
                n_blocks=2,
                attention_dropout=0.2,
                ffn_d_hidden=6,
                ffn_dropout=0.2,
                residual_dropout=0.0,
                d_out=d_out,
            ) 
        else:
            raise NotImplementedError

        self.model.to(self.device)
        optimizer = (
            self.model.make_default_optimizer()
            if isinstance(self.model, rtdl.FTTransformer)
            else torch.optim.AdamW(self.model.parameters(), lr=lr, weight_decay=weight_decay)
        )
        loss_fn = (
            F.binary_cross_entropy_with_logits
            if task_type == 'binclass'
            else F.cross_entropy
            if task_type == 'multiclass'
            else F.mse_loss
        )

        # Create a dataloader for batches of indices
        # Docs: https://yura52.github.io/zero/reference/api/zero.data.IndexLoader.html
        train_loader = delu.data.IndexLoader(len(X['train']), self.batch_size, device=self.device)

        # Create a progress tracker for early stopping
        # Docs: https://yura52.github.io/zero/reference/api/zero.ProgressTracker.html
        progress = delu.ProgressTracker(patience=100)

        # training
        # report_frequency = len(X['train']) // self.batch_size // 5

        for epoch in range(1, self.n_epochs + 1):
            loss_tmp = []
            for iteration, batch_idx in enumerate(train_loader):
                self.model.train()
                optimizer.zero_grad()
                x_batch = X['train'][batch_idx]
                y_batch = y['train'][batch_idx]
                loss = loss_fn(self.apply_model(x_batch).squeeze(1), y_batch)
                loss_tmp.append(loss.item())
                loss.backward()
                optimizer.step()
                # if iteration % report_frequency == 0:
                #     print(f'(epoch) {epoch} (batch) {iteration} (loss) {loss.item():.4f}')

            loss_.append(sum(loss_tmp)/len(loss_tmp))
            _, val_metric = self.evaluate(X=X['val'], y=y['val'])
            print(f'Epoch {epoch:03d} | Validation metric: {val_metric:.4f}', end='')
            progress.update((-1 if task_type == 'regression' else 1) * val_metric)
            if progress.success:
                print(' <<< BEST VALIDATION EPOCH', end='')
            print()
            # 验证
            # =========================================================
            # output predicted anomaly score on testing set
            score = self.predict_score(X_test)
            # evaluation
            result = utils.metric(y_true=y_test, y_score=score)
            aucroc.append(result['aucroc'])
            aucpr.append(result['aucpr'])
            # ==========================================================
            if progress.fail:
                break

        return self

    def predict_score(self, X):
        X = torch.from_numpy(X).float().to(self.device)
        score, _ = self.evaluate(X=X, y=None)
        return score

# %%
seed = 42
clf=FTTransformer(seed,"ResNet",n_epochs=480,batch_size=256)
aucroc = []
aucpr = []
loss_ = []
clf = clf.fit(X_train=X_train, y_train=y_train.squeeze(1),X_test=X_test,y_test=y_test)
#==========================
import platform
y_val_scores = clf.predict_score(X_val)   #返回未知数据上的异常值 (分值越大越异常) # outlier scores
#记录文件名和对应的异常得分
predict_result={}
for i in tqdm(range(len(test1_files))):
    file=test1_files[i]
    #如果是window系统：
    if platform.system().lower() == 'windows':
        name=file.split('\\')[-1]
    #如果是linux系统
    elif platform.system().lower() == 'linux':
        name=file.split('/')[-1]
    predict_result[name]=y_val_scores[i]
predict_score=pd.DataFrame(list(predict_result.items()),columns=['file_name','score'])#列名必须为这俩个
predict_score.to_csv(f'submision.csv',index = False) #保存为比赛要求的csv文件
# Out:
# Epoch 001 | Validation metric: 0.8940 <<< BEST VALIDATION EPOCH
# Epoch 002 | Validation metric: 0.9269 <<< BEST VALIDATION EPOCH
# Epoch 003 | Validation metric: 0.9629 <<< BEST VALIDATION EPOCH
# Epoch 004 | Validation metric: 0.9699 <<< BEST VALIDATION EPOCH
# Epoch 005 | Validation metric: 0.9779 <<< BEST VALIDATION EPOCH
# Epoch 006 | Validation metric: 0.9833 <<< BEST VALIDATION EPOCH
# Epoch 007 | Validation metric: 0.9864 <<< BEST VALIDATION EPOCH
# Epoch 008 | Validation metric: 0.9856
# Epoch 009 | Validation metric: 0.9874 <<< BEST VALIDATION EPOCH
# Epoch 010 | Validation metric: 0.9908 <<< BEST VALIDATION EPOCH
# Epoch 011 | Validation metric: 0.9913 <<< BEST VALIDATION EPOCH
# Epoch 012 | Validation metric: 0.9914 <<< BEST VALIDATION EPOCH
# Epoch 013 | Validation metric: 0.9935 <<< BEST VALIDATION EPOCH
# Epoch 014 | Validation metric: 0.9905
# Epoch 015 | Validation metric: 0.9945 <<< BEST VALIDATION EPOCH
# Epoch 016 | Validation metric: 0.9943
# Epoch 017 | Validation metric: 0.9938
# Epoch 018 | Validation metric: 0.9946 <<< BEST VALIDATION EPOCH
# Epoch 019 | Validation metric: 0.9934
# Epoch 020 | Validation metric: 0.9963 <<< BEST VALIDATION EPOCH
# Epoch 021 | Validation metric: 0.9966 <<< BEST VALIDATION EPOCH
# Epoch 022 | Validation metric: 0.9967 <<< BEST VALIDATION EPOCH
# Epoch 023 | Validation metric: 0.9962
# Epoch 024 | Validation metric: 0.9966
# Epoch 025 | Validation metric: 0.9952
# Epoch 026 | Validation metric: 0.9968 <<< BEST VALIDATION EPOCH
# Epoch 027 | Validation metric: 0.9970 <<< BEST VALIDATION EPOCH
# Epoch 028 | Validation metric: 0.9957
# Epoch 029 | Validation metric: 0.9973 <<< BEST VALIDATION EPOCH
# Epoch 030 | Validation metric: 0.9973
# Epoch 031 | Validation metric: 0.9977 <<< BEST VALIDATION EPOCH
# Epoch 032 | Validation metric: 0.9964
# Epoch 033 | Validation metric: 0.9977
# Epoch 034 | Validation metric: 0.9967
# Epoch 035 | Validation metric: 0.9976
# Epoch 036 | Validation metric: 0.9974
# Epoch 037 | Validation metric: 0.9981 <<< BEST VALIDATION EPOCH
# Epoch 038 | Validation metric: 0.9981 <<< BEST VALIDATION EPOCH
# Epoch 039 | Validation metric: 0.9979
# Epoch 040 | Validation metric: 0.9977
# Epoch 041 | Validation metric: 0.9979
# Epoch 042 | Validation metric: 0.9984 <<< BEST VALIDATION EPOCH
# Epoch 043 | Validation metric: 0.9975
# Epoch 044 | Validation metric: 0.9973
# Epoch 045 | Validation metric: 0.9972
# Epoch 046 | Validation metric: 0.9982
# Epoch 047 | Validation metric: 0.9980
# Epoch 048 | Validation metric: 0.9981
# Epoch 049 | Validation metric: 0.9984 <<< BEST VALIDATION EPOCH
# Epoch 050 | Validation metric: 0.9982
# Epoch 051 | Validation metric: 0.9978
# Epoch 052 | Validation metric: 0.9981
# Epoch 053 | Validation metric: 0.9985 <<< BEST VALIDATION EPOCH
# Epoch 054 | Validation metric: 0.9980
# Epoch 055 | Validation metric: 0.9987 <<< BEST VALIDATION EPOCH
# Epoch 056 | Validation metric: 0.9979
# Epoch 057 | Validation metric: 0.9979
# Epoch 058 | Validation metric: 0.9979
# Epoch 059 | Validation metric: 0.9978
# Epoch 060 | Validation metric: 0.9977
# Epoch 061 | Validation metric: 0.9986
# Epoch 062 | Validation metric: 0.9970
# Epoch 063 | Validation metric: 0.9984
# Epoch 064 | Validation metric: 0.9986
# Epoch 065 | Validation metric: 0.9987
# Epoch 066 | Validation metric: 0.9987
# Epoch 067 | Validation metric: 0.9982
# Epoch 068 | Validation metric: 0.9989 <<< BEST VALIDATION EPOCH
# Epoch 069 | Validation metric: 0.9986
# Epoch 070 | Validation metric: 0.9989
# Epoch 071 | Validation metric: 0.9978
# Epoch 072 | Validation metric: 0.9987
# Epoch 073 | Validation metric: 0.9978
# Epoch 074 | Validation metric: 0.9979
# Epoch 075 | Validation metric: 0.9987
# Epoch 076 | Validation metric: 0.9987
# Epoch 077 | Validation metric: 0.9980
# Epoch 078 | Validation metric: 0.9983
# Epoch 079 | Validation metric: 0.9988
# Epoch 080 | Validation metric: 0.9989 <<< BEST VALIDATION EPOCH
# Epoch 081 | Validation metric: 0.9992 <<< BEST VALIDATION EPOCH
# Epoch 082 | Validation metric: 0.9992 <<< BEST VALIDATION EPOCH
# Epoch 083 | Validation metric: 0.9978
# Epoch 084 | Validation metric: 0.9990
# Epoch 085 | Validation metric: 0.9985
# Epoch 086 | Validation metric: 0.9987
# Epoch 087 | Validation metric: 0.9991
# Epoch 088 | Validation metric: 0.9990
# Epoch 089 | Validation metric: 0.9987
# Epoch 090 | Validation metric: 0.9991
# Epoch 091 | Validation metric: 0.9987
# Epoch 092 | Validation metric: 0.9982
# Epoch 093 | Validation metric: 0.9992
# Epoch 094 | Validation metric: 0.9987
# Epoch 095 | Validation metric: 0.9983
# Epoch 096 | Validation metric: 0.9988
# Epoch 097 | Validation metric: 0.9988
# Epoch 098 | Validation metric: 0.9991
# Epoch 099 | Validation metric: 0.9988
# Epoch 100 | Validation metric: 0.9991
# Epoch 101 | Validation metric: 0.9991
# Epoch 102 | Validation metric: 0.9989
# Epoch 103 | Validation metric: 0.9988
# Epoch 104 | Validation metric: 0.9989
# Epoch 105 | Validation metric: 0.9983
# Epoch 106 | Validation metric: 0.9992
# Epoch 107 | Validation metric: 0.9987
# Epoch 108 | Validation metric: 0.9987
# Epoch 109 | Validation metric: 0.9988
# Epoch 110 | Validation metric: 0.9993 <<< BEST VALIDATION EPOCH
# Epoch 111 | Validation metric: 0.9988
# Epoch 112 | Validation metric: 0.9990
# Epoch 113 | Validation metric: 0.9989
# Epoch 114 | Validation metric: 0.9990
# Epoch 115 | Validation metric: 0.9990
# Epoch 116 | Validation metric: 0.9988
# Epoch 117 | Validation metric: 0.9977
# Epoch 118 | Validation metric: 0.9989
# Epoch 119 | Validation metric: 0.9993
# Epoch 120 | Validation metric: 0.9991
# Epoch 121 | Validation metric: 0.9992
# Epoch 122 | Validation metric: 0.9986
# Epoch 123 | Validation metric: 0.9994 <<< BEST VALIDATION EPOCH
# Epoch 124 | Validation metric: 0.9982
# Epoch 125 | Validation metric: 0.9992
# Epoch 126 | Validation metric: 0.9990
# Epoch 127 | Validation metric: 0.9987
# Epoch 128 | Validation metric: 0.9990
# Epoch 129 | Validation metric: 0.9991
# Epoch 130 | Validation metric: 0.9989
# Epoch 131 | Validation metric: 0.9986
# Epoch 132 | Validation metric: 0.9993
# Epoch 133 | Validation metric: 0.9987
# Epoch 134 | Validation metric: 0.9987
# Epoch 135 | Validation metric: 0.9994 <<< BEST VALIDATION EPOCH
# Epoch 136 | Validation metric: 0.9992
# Epoch 137 | Validation metric: 0.9992
# Epoch 138 | Validation metric: 0.9993
# Epoch 139 | Validation metric: 0.9993
# Epoch 140 | Validation metric: 0.9990
# Epoch 141 | Validation metric: 0.9994 <<< BEST VALIDATION EPOCH
# Epoch 142 | Validation metric: 0.9988
# Epoch 143 | Validation metric: 0.9993
# Epoch 144 | Validation metric: 0.9992
# Epoch 145 | Validation metric: 0.9992
# Epoch 146 | Validation metric: 0.9992
# Epoch 147 | Validation metric: 0.9988
# Epoch 148 | Validation metric: 0.9987
# Epoch 149 | Validation metric: 0.9994
# Epoch 150 | Validation metric: 0.9994 <<< BEST VALIDATION EPOCH
# Epoch 151 | Validation metric: 0.9992
# Epoch 152 | Validation metric: 0.9992
# Epoch 153 | Validation metric: 0.9992
# Epoch 154 | Validation metric: 0.9993
# Epoch 155 | Validation metric: 0.9993
# Epoch 156 | Validation metric: 0.9992
# Epoch 157 | Validation metric: 0.9993
# Epoch 158 | Validation metric: 0.9992
# Epoch 159 | Validation metric: 0.9990
# Epoch 160 | Validation metric: 0.9991
# Epoch 161 | Validation metric: 0.9993
# Epoch 162 | Validation metric: 0.9993
# Epoch 163 | Validation metric: 0.9991
# Epoch 164 | Validation metric: 0.9995 <<< BEST VALIDATION EPOCH
# Epoch 165 | Validation metric: 0.9994
# Epoch 166 | Validation metric: 0.9996 <<< BEST VALIDATION EPOCH
# Epoch 167 | Validation metric: 0.9990
# Epoch 168 | Validation metric: 0.9995
# Epoch 169 | Validation metric: 0.9995
# Epoch 170 | Validation metric: 0.9994
# Epoch 171 | Validation metric: 0.9996
# Epoch 172 | Validation metric: 0.9992
# Epoch 173 | Validation metric: 0.9990
# Epoch 174 | Validation metric: 0.9994
# Epoch 175 | Validation metric: 0.9989
# Epoch 176 | Validation metric: 0.9994
# Epoch 177 | Validation metric: 0.9995
# Epoch 178 | Validation metric: 0.9994
# Epoch 179 | Validation metric: 0.9993
# Epoch 180 | Validation metric: 0.9992
# Epoch 181 | Validation metric: 0.9995
# Epoch 182 | Validation metric: 0.9996 <<< BEST VALIDATION EPOCH
# Epoch 183 | Validation metric: 0.9993
# Epoch 184 | Validation metric: 0.9993
# Epoch 185 | Validation metric: 0.9994
# Epoch 186 | Validation metric: 0.9991
# Epoch 187 | Validation metric: 0.9990
# Epoch 188 | Validation metric: 0.9992
# Epoch 189 | Validation metric: 0.9995
# Epoch 190 | Validation metric: 0.9992
# Epoch 191 | Validation metric: 0.9993
# Epoch 192 | Validation metric: 0.9995
# Epoch 193 | Validation metric: 0.9992
# Epoch 194 | Validation metric: 0.9993
# Epoch 195 | Validation metric: 0.9995
# Epoch 196 | Validation metric: 0.9997 <<< BEST VALIDATION EPOCH
# Epoch 197 | Validation metric: 0.9995
# Epoch 198 | Validation metric: 0.9994
# Epoch 199 | Validation metric: 0.9995
# Epoch 200 | Validation metric: 0.9995
# Epoch 201 | Validation metric: 0.9996
# Epoch 202 | Validation metric: 0.9996
# Epoch 203 | Validation metric: 0.9994
# Epoch 204 | Validation metric: 0.9993
# Epoch 205 | Validation metric: 0.9993
# Epoch 206 | Validation metric: 0.9994
# Epoch 207 | Validation metric: 0.9992
# Epoch 208 | Validation metric: 0.9994
# Epoch 209 | Validation metric: 0.9995
# Epoch 210 | Validation metric: 0.9990
# Epoch 211 | Validation metric: 0.9995
# Epoch 212 | Validation metric: 0.9985
# Epoch 213 | Validation metric: 0.9989
# Epoch 214 | Validation metric: 0.9994
# Epoch 215 | Validation metric: 0.9996
# Epoch 216 | Validation metric: 0.9996
# Epoch 217 | Validation metric: 0.9995
# Epoch 218 | Validation metric: 0.9996
# Epoch 219 | Validation metric: 0.9996
# Epoch 220 | Validation metric: 0.9994
# Epoch 221 | Validation metric: 0.9995
# Epoch 222 | Validation metric: 0.9997 <<< BEST VALIDATION EPOCH
# Epoch 223 | Validation metric: 0.9996
# Epoch 224 | Validation metric: 0.9996
# Epoch 225 | Validation metric: 0.9990
# Epoch 226 | Validation metric: 0.9993
# Epoch 227 | Validation metric: 0.9994
# Epoch 228 | Validation metric: 0.9993
# Epoch 229 | Validation metric: 0.9990
# Epoch 230 | Validation metric: 0.9988
# Epoch 231 | Validation metric: 0.9997 <<< BEST VALIDATION EPOCH
# Epoch 232 | Validation metric: 0.9994
# Epoch 233 | Validation metric: 0.9997
# Epoch 234 | Validation metric: 0.9997
# Epoch 235 | Validation metric: 0.9992
# Epoch 236 | Validation metric: 0.9997
# Epoch 237 | Validation metric: 0.9996
# Epoch 238 | Validation metric: 0.9995
# Epoch 239 | Validation metric: 0.9991
# Epoch 240 | Validation metric: 0.9994
# Epoch 241 | Validation metric: 0.9995
# Epoch 242 | Validation metric: 0.9997
# Epoch 243 | Validation metric: 0.9997
# Epoch 244 | Validation metric: 0.9992
# Epoch 245 | Validation metric: 0.9997
# Epoch 246 | Validation metric: 0.9997
# Epoch 247 | Validation metric: 0.9996
# Epoch 248 | Validation metric: 0.9996
# Epoch 249 | Validation metric: 0.9995
# Epoch 250 | Validation metric: 0.9986
# Epoch 251 | Validation metric: 0.9997
# Epoch 252 | Validation metric: 0.9996
# Epoch 253 | Validation metric: 0.9992
# Epoch 254 | Validation metric: 0.9994
# Epoch 255 | Validation metric: 0.9997
# Epoch 256 | Validation metric: 0.9993
# Epoch 257 | Validation metric: 0.9993
# Epoch 258 | Validation metric: 0.9996
# Epoch 259 | Validation metric: 0.9994
# Epoch 260 | Validation metric: 0.9997 <<< BEST VALIDATION EPOCH
# Epoch 261 | Validation metric: 0.9997
# Epoch 262 | Validation metric: 0.9996
# Epoch 263 | Validation metric: 0.9997
# Epoch 264 | Validation metric: 0.9996
# Epoch 265 | Validation metric: 0.9997
# Epoch 266 | Validation metric: 0.9997
# Epoch 267 | Validation metric: 0.9996
# Epoch 268 | Validation metric: 0.9995
# Epoch 269 | Validation metric: 0.9998 <<< BEST VALIDATION EPOCH
# Epoch 270 | Validation metric: 0.9996
# Epoch 271 | Validation metric: 0.9995
# Epoch 272 | Validation metric: 0.9994
# Epoch 273 | Validation metric: 0.9996
# Epoch 274 | Validation metric: 0.9998
# Epoch 275 | Validation metric: 0.9997
# Epoch 276 | Validation metric: 0.9997
# Epoch 277 | Validation metric: 0.9995
# Epoch 278 | Validation metric: 0.9996
# Epoch 279 | Validation metric: 0.9994
# Epoch 280 | Validation metric: 0.9996
# Epoch 281 | Validation metric: 0.9990
# Epoch 282 | Validation metric: 0.9996
# Epoch 283 | Validation metric: 0.9998
# Epoch 284 | Validation metric: 0.9998 <<< BEST VALIDATION EPOCH
# Epoch 285 | Validation metric: 0.9996
# Epoch 286 | Validation metric: 0.9994
# Epoch 287 | Validation metric: 0.9995
# Epoch 288 | Validation metric: 0.9995
# Epoch 289 | Validation metric: 0.9996
# Epoch 290 | Validation metric: 0.9995
# Epoch 291 | Validation metric: 0.9996
# Epoch 292 | Validation metric: 0.9994
# Epoch 293 | Validation metric: 0.9997
# Epoch 294 | Validation metric: 0.9993
# Epoch 295 | Validation metric: 0.9996
# Epoch 296 | Validation metric: 0.9994
# Epoch 297 | Validation metric: 0.9992
# Epoch 298 | Validation metric: 0.9995
# Epoch 299 | Validation metric: 0.9997
# Epoch 300 | Validation metric: 0.9994
# Epoch 301 | Validation metric: 0.9997
# Epoch 302 | Validation metric: 0.9994
# Epoch 303 | Validation metric: 0.9993
# Epoch 304 | Validation metric: 0.9996
# Epoch 305 | Validation metric: 0.9997
# Epoch 306 | Validation metric: 0.9996
# Epoch 307 | Validation metric: 0.9997
# Epoch 308 | Validation metric: 0.9996
# Epoch 309 | Validation metric: 0.9997
# Epoch 310 | Validation metric: 0.9998
# Epoch 311 | Validation metric: 0.9997
# Epoch 312 | Validation metric: 0.9990
# Epoch 313 | Validation metric: 0.9998
# Epoch 314 | Validation metric: 0.9995
# Epoch 315 | Validation metric: 0.9991
# Epoch 316 | Validation metric: 0.9998
# Epoch 317 | Validation metric: 0.9997
# Epoch 318 | Validation metric: 0.9995
# Epoch 319 | Validation metric: 0.9995
# Epoch 320 | Validation metric: 0.9993
# Epoch 321 | Validation metric: 0.9997
# Epoch 322 | Validation metric: 0.9998
# Epoch 323 | Validation metric: 0.9990
# Epoch 324 | Validation metric: 0.9996
# Epoch 325 | Validation metric: 0.9997
# Epoch 326 | Validation metric: 0.9994
# Epoch 327 | Validation metric: 0.9994
# Epoch 328 | Validation metric: 0.9997
# Epoch 329 | Validation metric: 0.9993
# Epoch 330 | Validation metric: 0.9998
# Epoch 331 | Validation metric: 0.9995
# Epoch 332 | Validation metric: 0.9998
# Epoch 333 | Validation metric: 0.9992
# Epoch 334 | Validation metric: 0.9996
# Epoch 335 | Validation metric: 0.9982
# Epoch 336 | Validation metric: 0.9993
# Epoch 337 | Validation metric: 0.9998
# Epoch 338 | Validation metric: 0.9997
# Epoch 339 | Validation metric: 0.9997
# Epoch 340 | Validation metric: 0.9997
# Epoch 341 | Validation metric: 0.9997
# Epoch 342 | Validation metric: 0.9997
# Epoch 343 | Validation metric: 0.9989
# Epoch 344 | Validation metric: 0.9997
# Epoch 345 | Validation metric: 0.9997
# Epoch 346 | Validation metric: 0.9996
# Epoch 347 | Validation metric: 0.9997
# Epoch 348 | Validation metric: 0.9996
# Epoch 349 | Validation metric: 0.9998
# Epoch 350 | Validation metric: 0.9998
# Epoch 351 | Validation metric: 0.9997
# Epoch 352 | Validation metric: 0.9996
# Epoch 353 | Validation metric: 0.9998
# Epoch 354 | Validation metric: 0.9995
# Epoch 355 | Validation metric: 0.9998
# Epoch 356 | Validation metric: 0.9997
# Epoch 357 | Validation metric: 0.9998 <<< BEST VALIDATION EPOCH
# Epoch 358 | Validation metric: 0.9997
# Epoch 359 | Validation metric: 0.9998
# Epoch 360 | Validation metric: 0.9998 <<< BEST VALIDATION EPOCH
# Epoch 361 | Validation metric: 0.9988
# Epoch 362 | Validation metric: 0.9998
# Epoch 363 | Validation metric: 0.9998
# Epoch 364 | Validation metric: 0.9998 <<< BEST VALIDATION EPOCH
# Epoch 365 | Validation metric: 0.9997
# Epoch 366 | Validation metric: 0.9998
# Epoch 367 | Validation metric: 0.9995
# Epoch 368 | Validation metric: 0.9997
# Epoch 369 | Validation metric: 0.9997
# Epoch 370 | Validation metric: 0.9995
# Epoch 371 | Validation metric: 0.9991
# Epoch 372 | Validation metric: 0.9998
# Epoch 373 | Validation metric: 0.9998
# Epoch 374 | Validation metric: 0.9997
# Epoch 375 | Validation metric: 0.9997
# Epoch 376 | Validation metric: 0.9996
# Epoch 377 | Validation metric: 0.9996
# Epoch 378 | Validation metric: 0.9998
# Epoch 379 | Validation metric: 0.9996
# Epoch 380 | Validation metric: 0.9997
# Epoch 381 | Validation metric: 0.9989
# Epoch 382 | Validation metric: 0.9998
# Epoch 383 | Validation metric: 0.9997
# Epoch 384 | Validation metric: 0.9997
# Epoch 385 | Validation metric: 0.9996
# Epoch 386 | Validation metric: 0.9998
# Epoch 387 | Validation metric: 0.9996
# Epoch 388 | Validation metric: 0.9998
# Epoch 389 | Validation metric: 0.9997
# Epoch 390 | Validation metric: 0.9998
# Epoch 391 | Validation metric: 0.9998
# Epoch 392 | Validation metric: 0.9997
# Epoch 393 | Validation metric: 0.9997
# Epoch 394 | Validation metric: 0.9997
# Epoch 395 | Validation metric: 0.9994
# Epoch 396 | Validation metric: 0.9996
# Epoch 397 | Validation metric: 0.9998 <<< BEST VALIDATION EPOCH
# Epoch 398 | Validation metric: 0.9999 <<< BEST VALIDATION EPOCH
# Epoch 399 | Validation metric: 0.9997
# Epoch 400 | Validation metric: 0.9998
# Epoch 401 | Validation metric: 0.9997
# Epoch 402 | Validation metric: 0.9997
# Epoch 403 | Validation metric: 0.9997
# Epoch 404 | Validation metric: 0.9997
# Epoch 405 | Validation metric: 0.9998
# Epoch 406 | Validation metric: 0.9998
# Epoch 407 | Validation metric: 0.9998
# Epoch 408 | Validation metric: 0.9997
# Epoch 409 | Validation metric: 0.9997
# Epoch 410 | Validation metric: 0.9996
# Epoch 411 | Validation metric: 0.9998
# Epoch 412 | Validation metric: 0.9993
# Epoch 413 | Validation metric: 0.9995
# Epoch 414 | Validation metric: 0.9998
# Epoch 415 | Validation metric: 0.9998
# Epoch 416 | Validation metric: 0.9995
# Epoch 417 | Validation metric: 0.9997
# Epoch 418 | Validation metric: 0.9997
# Epoch 419 | Validation metric: 0.9996
# Epoch 420 | Validation metric: 0.9996
# Epoch 421 | Validation metric: 0.9996
# Epoch 422 | Validation metric: 0.9997
# Epoch 423 | Validation metric: 0.9997
# Epoch 424 | Validation metric: 0.9997
# Epoch 425 | Validation metric: 0.9998
# Epoch 426 | Validation metric: 0.9998
# Epoch 427 | Validation metric: 0.9997
# Epoch 428 | Validation metric: 0.9997
# Epoch 429 | Validation metric: 0.9997
# Epoch 430 | Validation metric: 0.9999 <<< BEST VALIDATION EPOCH
# Epoch 431 | Validation metric: 0.9997
# Epoch 432 | Validation metric: 0.9998
# Epoch 433 | Validation metric: 0.9996
# Epoch 434 | Validation metric: 0.9998
# Epoch 435 | Validation metric: 0.9997
# Epoch 436 | Validation metric: 0.9997
# Epoch 437 | Validation metric: 0.9998
# Epoch 438 | Validation metric: 0.9995
# Epoch 439 | Validation metric: 0.9998
# Epoch 440 | Validation metric: 0.9999 <<< BEST VALIDATION EPOCH
# Epoch 441 | Validation metric: 0.9998
# Epoch 442 | Validation metric: 0.9998
# Epoch 443 | Validation metric: 0.9996
# Epoch 444 | Validation metric: 0.9997
# Epoch 445 | Validation metric: 0.9998
# Epoch 446 | Validation metric: 0.9996
# Epoch 447 | Validation metric: 0.9997
# Epoch 448 | Validation metric: 0.9996
# Epoch 449 | Validation metric: 0.9995
# Epoch 450 | Validation metric: 0.9998
# Epoch 451 | Validation metric: 0.9998
# Epoch 452 | Validation metric: 0.9999
# Epoch 453 | Validation metric: 0.9999
# Epoch 454 | Validation metric: 0.9996
# Epoch 455 | Validation metric: 0.9997
# Epoch 456 | Validation metric: 0.9998
# Epoch 457 | Validation metric: 0.9998
# Epoch 458 | Validation metric: 0.9997
# Epoch 459 | Validation metric: 0.9992
# Epoch 460 | Validation metric: 0.9993
# Epoch 461 | Validation metric: 0.9998
# Epoch 462 | Validation metric: 0.9997
# Epoch 463 | Validation metric: 0.9997
# Epoch 464 | Validation metric: 0.9997
# Epoch 465 | Validation metric: 0.9997
# Epoch 466 | Validation metric: 0.9997
# Epoch 467 | Validation metric: 0.9999
# Epoch 468 | Validation metric: 0.9997
# Epoch 469 | Validation metric: 0.9998
# Epoch 470 | Validation metric: 0.9998
# Epoch 471 | Validation metric: 0.9997
# Epoch 472 | Validation metric: 0.9996
# Epoch 473 | Validation metric: 0.9998
# Epoch 474 | Validation metric: 0.9997
# Epoch 475 | Validation metric: 0.9998
# Epoch 476 | Validation metric: 0.9998
# Epoch 477 | Validation metric: 0.9999
# Epoch 478 | Validation metric: 0.9998
# Epoch 479 | Validation metric: 0.9997
# Epoch 480 | Validation metric: 0.9998
# Epoch 481 | Validation metric: 0.9998
# Epoch 482 | Validation metric: 0.9998
# Epoch 483 | Validation metric: 0.9998
# Epoch 484 | Validation metric: 0.9998
# Epoch 485 | Validation metric: 0.9998
# Epoch 486 | Validation metric: 0.9999 <<< BEST VALIDATION EPOCH
# Epoch 487 | Validation metric: 0.9998
# Epoch 488 | Validation metric: 0.9994
# Epoch 489 | Validation metric: 0.9997
# Epoch 490 | Validation metric: 0.9998
# Epoch 491 | Validation metric: 0.9998
# Epoch 492 | Validation metric: 0.9997
# Epoch 493 | Validation metric: 0.9997
# Epoch 494 | Validation metric: 0.9999
# Epoch 495 | Validation metric: 0.9998
# Epoch 496 | Validation metric: 0.9996
# Epoch 497 | Validation metric: 0.9998
# Epoch 498 | Validation metric: 0.9995
# Epoch 499 | Validation metric: 0.9998
# Epoch 500 | Validation metric: 0.9999
# Epoch 501 | Validation metric: 0.9997
# Epoch 502 | Validation metric: 0.9999
# Epoch 503 | Validation metric: 0.9997
# Epoch 504 | Validation metric: 0.9998
# Epoch 505 | Validation metric: 0.9998
# Epoch 506 | Validation metric: 0.9996
# Epoch 507 | Validation metric: 0.9998
# Epoch 508 | Validation metric: 0.9996
# Epoch 509 | Validation metric: 0.9996
# Epoch 510 | Validation metric: 0.9996
# Epoch 511 | Validation metric: 0.9997
# Epoch 512 | Validation metric: 0.9994
# Epoch 513 | Validation metric: 0.9998
# Epoch 514 | Validation metric: 0.9998
# Epoch 515 | Validation metric: 0.9997
# Epoch 516 | Validation metric: 0.9998
# 100%|██████████████████████████████████████████████████████████████████████████| 6234/6234 [00:00<00:00, 275640.85it/s]

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=((10,8)))
plt.subplot(221)
plt.plot(aucroc,label="aucroc")
plt.plot(aucpr,label="aucpr")
plt.legend()
plt.subplot(222)
plt.plot(loss_,label="loss")
plt.legend()
plt.show()
print(aucroc.index(max(aucroc)))
print(aucpr.index(max(aucpr)))
# Out:
# 480
# 480

# %%
clf.model
# Out:
# ResNet(
#   (first_layer): Linear(in_features=8, out_features=128, bias=True)
#   (blocks): Sequential(
#     (0): Block(
#       (normalization): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (linear_first): Linear(in_features=128, out_features=256, bias=True)
#       (activation): ReLU()
#       (dropout_first): Dropout(p=0.25, inplace=False)
#       (linear_second): Linear(in_features=256, out_features=128, bias=True)
#       (dropout_second): Dropout(p=0.0, inplace=False)
#     )
#     (1): Block(
#       (normalization): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (linear_first): Linear(in_features=128, out_features=256, bias=True)
#       (activation): ReLU()
#       (dropout_first): Dropout(p=0.25, inplace=False)
#       (linear_second): Linear(in_features=256, out_features=128, bias=True)
#       (dropout_second): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (head): Head(
#     (normalization): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU()
#     (linear): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
clf.model
# Out:
# MLP(
#   (blocks): Sequential(
#     (0): Block(
#       (linear): Linear(in_features=8, out_features=128, bias=True)
#       (activation): ReLU()
#       (dropout): Dropout(p=0.25, inplace=False)
#     )
#     (1): Block(
#       (linear): Linear(in_features=128, out_features=256, bias=True)
#       (activation): ReLU()
#       (dropout): Dropout(p=0.25, inplace=False)
#     )
#     (2): Block(
#       (linear): Linear(in_features=256, out_features=128, bias=True)
#       (activation): ReLU()
#       (dropout): Dropout(p=0.25, inplace=False)
#     )
#   )
#   (head): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
from thop import clever_format
from thop import profile
input = torch.randn(256, 8)
flops, params =profile(clf.model, inputs=(input,))
flops, params = clever_format([flops, params], "%.3f")
print(flops)
print(params)
# Out:
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm1d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# 34.243M
# 133.889K

# %%
from thop import clever_format
from thop import profile
input = torch.randn(256, 7)
flops, params =profile(clf.model, inputs=(input,))
flops, params = clever_format([flops, params], "%.3f")
print(flops)
print(params)
